# %%
import os
import shutil
import pandas as pd

#Set iteration of study and source path
study = 'Study2.0'
condition = 'Predict'
source_dir = (
    "/Users/sm6511/Downloads/raw4/"
)

#Destination path for files
dest_dir = (
    f"/Users/sm6511/Desktop/Prediction-Accomodation-Exp/"
    f"data/{study}/{condition}"
)
target_date = "2026-02-09"

os.makedirs(dest_dir, exist_ok=True)

# --- COLUMN TO CHECK ---
completion_col = "survey_debrief.block_1/debriefComplete"

moved = []
skipped = []


for fname in os.listdir(source_dir):
    if not fname.endswith(".csv"):
        continue

    if target_date not in fname:   # <-- only process files with the right date in the name
        continue

    src_path = os.path.join(source_dir, fname)

    src_path = os.path.join(source_dir, fname)

    try:
        df = pd.read_csv(src_path)
        df.columns = df.columns.str.strip()
    except Exception as e:
        print(f"Could not read {fname}: {e}")
        skipped.append((fname, "read error"))
        continue

    if completion_col not in df.columns:
        print(f"⚠️ Missing completion column in {fname}")
        skipped.append((fname, "missing column"))
        continue

    # Check if any row contains 'complete'
    is_complete = (
        df[completion_col]
        .astype(str)
        .str.lower()
        .eq("complete")
        .any()
    )

    if is_complete:
        dest_path = os.path.join(dest_dir, fname)
        shutil.move(src_path, dest_path)
        #print(f"[DRY RUN] Would move: {fname}")
        moved.append(fname)
        print(f" MOVED: {fname}")
    else:
        skipped.append((fname, "not complete"))

# --- SUMMARY ---
print("\n===== SUMMARY =====")
print(f"Moved files ({len(moved)}):")
for f in moved:
    print(f"  {f}")

print(f"\nSkipped files ({len(skipped)}):")
for f, reason in skipped:
    print(f"  {f} — {reason}")
# Out:
# ⚠️ Missing completion column in 149_test_2026-02-09_11h53.13.060.csv
#  MOVED: 214_test_2026-02-09_14h07.16.011.csv
#  MOVED: 082_test_2026-02-09_15h07.51.028.csv
#  MOVED: 113_test_2026-02-09_15h09.15.976.csv
#  MOVED: 087_test_2026-02-09_14h31.27.830.csv
# ⚠️ Missing completion column in 171_test_2026-02-09_15h04.37.986.csv
#  MOVED: 146_test_2026-02-09_15h10.55.942.csv
# ⚠️ Missing completion column in 087_test_2026-02-09_15h14.22.962.csv
# ⚠️ Missing completion column in 113_test_2026-02-09_15h05.06.011.csv
#  MOVED: 207_test_2026-02-09_15h11.21.096.csv
#  MOVED: 080_test_2026-02-09_14h03.42.750.csv
# Could not read PARTICIPANT_predict2_2026-02-09_14h02.20.935.csv: No columns to parse from file
#  MOVED: 048_test_2026-02-09_15h25.08.143.csv
#  MOVED: 034_test_2026-02-09_15h25.34.565.csv
#  MOVED: 182_test_2026-02-09_15h06.41.816.csv
#  MOVED: 030_test_2026-02-09_15h10.43.455.csv
#  MOVED: 091_test_2026-02-09_12h03.30.041.csv
#  MOVED: 065_test_2026-02-09_12h06.50.568.csv
# ⚠️ Missing completion column in 149_test_2026-02-09_15h30.18.142.csv
#  MOVED: 147_test_2026-02-09_13h06.35.574.csv
#  MOVED: 118_test_2026-02-09_14h05.00.923.csv
#  MOVED: 096_test_2026-02-09_15h08.29.168.csv
#  MOVED: 149_test_2026-02-09_15h05.50.520.csv
#  MOVED: 017_test_2026-02-09_15h03.11.130.csv
# ⚠️ Missing completion column in 161_test_2026-02-09_14h08.45.938.csv
#  MOVED: 033_test_2026-02-09_14h19.05.339.csv
# Could not read PARTICIPANT_predict2_2026-02-09_14h03.27.976.csv: No columns to parse from file
#  MOVED: 191_test_2026-02-09_12h02.28.282.csv
# ⚠️ Missing completion column in 033_test_2026-02-09_14h04.32.975.csv
#  MOVED: 161_test_2026-02-09_14h30.38.461.csv
#  MOVED: 171_test_2026-02-09_15h28.27.998.csv
# ⚠️ Missing completion column in 149_test_2026-02-09_15h02.35.930.csv
#  MOVED: 053_test_2026-02-09_14h38.02.074.csv
#  MOVED: 023_test_2026-02-09_15h04.09.735.csv
